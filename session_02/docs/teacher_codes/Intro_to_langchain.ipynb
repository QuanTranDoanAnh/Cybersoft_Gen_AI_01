# %%
import os 
from dotenv import load_dotenv 
from langchain_openai import ChatOpenAI

# %%
load_dotenv() 

llm = ChatOpenAI(
    model="gpt-5-mini", 
    temperature=0, 
    api_key=os.getenv("OPENAI_API_KEY")
)

# %%
messages = [
    ("system", "Bạn là một trợ lý AI, bạn sẽ trả lời bằng tiếng Việt"), 
    ("human", "Python là gì?")
]

# %%
result = llm.invoke(messages) 
result
# Out:
# AIMessage(content='Python là một ngôn ngữ lập trình bậc cao, thông dịch, và đa mô hình, được thiết kế để dễ đọc và dễ viết. Nó được tạo ra bởi Guido van Rossum và phát hành lần đầu vào đầu những năm 1990. Một số điểm chính:\n\n- Cú pháp rõ ràng, dùng thụt lề để phân cấp mã nguồn (ít dấu ngoặc nhọn).\n- Kiểu động (dynamic typing) và quản lý bộ nhớ tự động (garbage collection).\n- Hỗ trợ lập trình hướng đối tượng, thủ tục và lập trình hàm.\n- Thư viện tiêu chuẩn phong phú và hệ sinh thái gói lớn (cài đặt qua pip).\n- Python 3 là chuỗi phiên bản hiện được khuyến nghị; Python 2 đã ngừng hỗ trợ từ năm 2020.\n\nỨng dụng phổ biến: phát triển web (Django, Flask), khoa học dữ liệu và học máy (NumPy, pandas, scikit-learn, TensorFlow, PyTorch), tự động hóa và scripting, xử lý văn bản, ứng dụng mạng, và lập trình nhúng nhẹ.\n\nMột vài triển khai nổi bật: CPython (implement mặc định), PyPy (tối ưu hiệu năng), Jython (chạy trên JVM), IronPython (chạy trên .NET).\n\nVí dụ rất đơn giản (in ra màn hình):\nprint("Hello, world!")\n\nHàm tính tổng:\ndef tong(a, b):\n    return a + b\n\nprint(tong(3, 5))  # kết quả: 8\n\nNếu bạn muốn, tôi có thể hướng dẫn cách cài Python trên máy, tạo môi trường ảo (venv), hoặc bắt đầu với một dự án cụ thể. Bạn muốn học phần nào tiếp theo?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 764, 'prompt_tokens': 28, 'total_tokens': 792, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 384, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-mini-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-Dyca5ZwPYUMboJ0aHKkDa0iAZJG7Z', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f375e-2fb3-75e1-bb37-de2ff4af27b3-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 764, 'total_tokens': 792, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 384}})

# %%
result.content
# Out:
# 'Python là một ngôn ngữ lập trình bậc cao, thông dịch, và đa mô hình, được thiết kế để dễ đọc và dễ viết. Nó được tạo ra bởi Guido van Rossum và phát hành lần đầu vào đầu những năm 1990. Một số điểm chính:\n\n- Cú pháp rõ ràng, dùng thụt lề để phân cấp mã nguồn (ít dấu ngoặc nhọn).\n- Kiểu động (dynamic typing) và quản lý bộ nhớ tự động (garbage collection).\n- Hỗ trợ lập trình hướng đối tượng, thủ tục và lập trình hàm.\n- Thư viện tiêu chuẩn phong phú và hệ sinh thái gói lớn (cài đặt qua pip).\n- Python 3 là chuỗi phiên bản hiện được khuyến nghị; Python 2 đã ngừng hỗ trợ từ năm 2020.\n\nỨng dụng phổ biến: phát triển web (Django, Flask), khoa học dữ liệu và học máy (NumPy, pandas, scikit-learn, TensorFlow, PyTorch), tự động hóa và scripting, xử lý văn bản, ứng dụng mạng, và lập trình nhúng nhẹ.\n\nMột vài triển khai nổi bật: CPython (implement mặc định), PyPy (tối ưu hiệu năng), Jython (chạy trên JVM), IronPython (chạy trên .NET).\n\nVí dụ rất đơn giản (in ra màn hình):\nprint("Hello, world!")\n\nHàm tính tổng:\ndef tong(a, b):\n    return a + b\n\nprint(tong(3, 5))  # kết quả: 8\n\nNếu bạn muốn, tôi có thể hướng dẫn cách cài Python trên máy, tạo môi trường ảo (venv), hoặc bắt đầu với một dự án cụ thể. Bạn muốn học phần nào tiếp theo?'

# %%
from langchain_core.prompts import ChatPromptTemplate 

messages = [
    ("system", "Bạn là một trợ lý AI, bạn sẽ trả lời bằng {language}"), 
    ("human", "{input}")
]

prompt = ChatPromptTemplate.from_messages(messages)

# %%
chain = prompt | llm

# %%
result = chain.invoke({
    "language": "Bồ Đào Nha", 
    "input": "Python là gì?"
})
result.content
# Out:
# 'Python é uma linguagem de programação de alto nível, interpretada e de tipagem dinâmica, criada por Guido van Rossum e lançada em 1991. É multi‑paradigma (suporta programação procedural, orientada a objetos e funcional) e valoriza legibilidade e concisão de código.\n\nPrincipais características\n- Sintaxe clara e fácil de ler.\n- Grande biblioteca padrão e ecossistema de pacotes (pip).\n- Multiplataforma (Windows, macOS, Linux).\n- Vasta comunidade e muitos recursos de aprendizado.\n- Usos comuns: desenvolvimento web, ciência de dados, machine learning, automação, scripts, testes, computação científica e aplicações de back‑end.\n\nImplementações comuns\n- CPython (implementação de referência)\n- PyPy (foco em performance)\n- Jython (para JVM)\n- IronPython (para .NET)\n\nVersões\n- Python 2 chegou ao fim do suporte em 2020. Use Python 3.x (até 2024 a versão estável mais recente é Python 3.12).\n\nExemplo simples\nprint("Olá, mundo!")\nfor i in range(3):\n    print(i)\n\nComo começar\n- Baixe em python.org ou use gerenciadores de pacote.\n- Instale pacotes com pip: pip install nome_do_pacote\n- Documentação oficial: docs.python.org\n- Cursos e tutoriais: muitos gratuitos e pagos (ex.: tutorial oficial, plataformas como Coursera, Codecademy, YouTube).\n\nSe quiser, posso:\n- Ajudar a instalar o Python no seu sistema.\n- Recomendar um caminho de estudo conforme seu objetivo (web, dados, automação etc.).\n- Mostrar exemplos mais avançados.'
